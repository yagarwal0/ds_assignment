# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Five plts that we can plot using the Seaborn library are as follows:
# > Scatter Plot - It helps in finding relationship between two continuous variables.<br>
# > Line Plot - displays the current trend or change in a single variable over time.<br>
# > Bar Plot - compares the categorical variables by showing the average values between different categories.<br>
# > Histogram - tells the distribution of a single numerical value.<br>
# > Heatmap - visualizes the matrix of data using colour encoding.

# %% [markdown]
# # Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.

# %%
fmri = sns.load_dataset('fmri')

# %%
sns.lineplot(x='timepoint', y='signal', data=fmri, hue = 'event', style = 'region')
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.

# %%
titanic = sns.load_dataset('titanic')

plt.subplot(1,2,1)
sns.boxplot(x = 'pclass', y='age', data = titanic)

plt.subplot(1,2,2)
sns.boxplot(x = 'pclass', y='fare', data=titanic)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.

# %%
diamonds = sns.load_dataset('diamonds')
sns.histplot(x = 'price', data=diamonds, hue='cut')
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %% [markdown]
# # Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.

# %%
iris = sns.load_dataset('iris')
sns.pairplot(hue='species', data=iris)

# %% [markdown]
# # Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights = sns.load_dataset('flights')
sns.heatmap(flights.pivot("month", "year", "passengers"))
# Out:
# /tmp/ipykernel_3514/3167309009.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(flights.pivot("month", "year", "passengers"))
# <AxesSubplot: xlabel='year', ylabel='month'>
